# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
filepath = "C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\full_data.csv"
data = pd.read_csv(filepath)
data.head()
# Out:
#    Unnamed: 0   County    State  Total Population  Land Area (m^2)  \
# 0           0  Autauga  Alabama           55639.0           594.44
# 1           1  Baldwin  Alabama          218289.0          1589.78
# 2           2  Barbour  Alabama           25026.0           884.88
# 3           3     Bibb  Alabama           22374.0           622.58
# 4           4   Blount  Alabama           57755.0           644.78
#
#    Population Density (per m^2)  Median Gross Rent  Income per capita  \
# 0                     93.599018             1011.0            29804.0
# 1                    137.307678             1032.0            33751.0
# 2                     28.281801              587.0            20074.0
# 3                     35.937550              693.0            22626.0
# 4                     89.573188              666.0            25457.0
#
#    Less Than A High School Diploma, 2017-21  \
# 0                                    4126.0
# 1                                   14555.0
# ...

# %% [markdown]
# ## Education Visualizations

# %%
#function for regression
def linreg_function(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    return (regress_values, slope, intercept, rvalue)

# %% [markdown]
# ### Low Pop Density
# #### Base Stats

# %%
# create data frame
low_den_df = data.loc[data["Population Density (per m^2)"] < 250]
#low_den_df.head()
low_den_df.columns
# Out:
# Index(['Unnamed: 0', 'County', 'State', 'Total Population', 'Land Area (m^2)',
#        'Population Density (per m^2)', 'Median Gross Rent',
#        'Income per capita', 'Less Than A High School Diploma, 2017-21',
#        'High School Diploma Only, 2017-21',
#        'Some College Or Associate'S Degree, 2017-21',
#        'Bachelor'S Degree Or Higher, 2017-21',
#        'Percent Of Adults With Less Than A High School Diploma, 2017-21',
#        'Percent Of Adults With A High School Diploma Only, 2017-21',
#        'Percent Of Adults Completing Some College Or Associate'S Degree, 2017-21',
#        'Percent Of Adults With A Bachelor'S Degree Or Higher, 2017-21',
#        'Estimate Of People Of All Ages In Poverty 2020',
#        'Estimated Percent Of People Of All Ages In Poverty 2020',
#        'Employed_2020', 'Unemployed_2020', 'Unemployment_Rate_2020',
#        'Median_Household_Income_2020',
# ...

# %%
xValues = low_den_df["Population Density (per m^2)"]
y1 = low_den_df["Less Than A High School Diploma, 2017-21"]
y2 = low_den_df["High School Diploma Only, 2017-21"]
y3 = low_den_df["Some College Or Associate'S Degree, 2017-21"]
y4 = low_den_df["Bachelor'S Degree Or Higher, 2017-21"]

# %%
plt.scatter(xValues, y1)

plt.title("Population Density (m^2) vs Number of people with \n Less Than A High School Diploma")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y1)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 45))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-less-than-hs-diploma")

# %%
plt.scatter(xValues, y2)

plt.title("Population Density (m^2) vs Number of People with \n High School Diploma Only")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y2)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 50))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-hs-diploma-only")

# %%
plt.scatter(xValues, y3)

plt.title("Population Density (m^2) vs Number of People with \n Some College or Associate's Degree")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y3)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 45))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-some-college")

# %%
plt.scatter(xValues, y4)

plt.title("Population Density (m^2) vs Number of People with \n Bachelor's Degree or Higher")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y4)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 60))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-bachelors-degree")

# %% [markdown]
# ### Low Pop Density
# #### Percent Stats

# %%
xValues = low_den_df["Population Density (per m^2)"]
y1 = low_den_df["Percent Of Adults With Less Than A High School Diploma, 2017-21"]
y2 = low_den_df["Percent Of Adults With A High School Diploma Only, 2017-21"]
y3 = low_den_df["Percent Of Adults Completing Some College Or Associate'S Degree, 2017-21"]
y4 = low_den_df["Percent Of Adults With A Bachelor'S Degree Or Higher, 2017-21"]

# %%
plt.scatter(xValues, y1)

plt.title("Population Density (m^2) vs Percent of Adults with \n Less than a High School Diploma")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y1)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 45))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-less-than-hs-diploma")

# %%
plt.scatter(xValues, y2)

plt.title("Population Density (m^2) vs Percent of Adults with \n a High School Diploma only")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y2)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 50))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-hs-diploma-only")

# %%
plt.scatter(xValues, y3)

plt.title("Population Density (m^2) vs Percent of Adults who have \n Completed some College or Associate's Degree")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y3)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 45))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-some-college")

# %%
plt.scatter(xValues, y4)

plt.title("Population Density (m^2) vs Percent of Adults with \n a Bachelor's Degree or Higher")
plt.xlabel("Population Density (m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, y4)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 60))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-bachelors-degree")

# %% [markdown]
# ### High Pop Density
# #### Base Stats

# %%
#create data frame
high_den_df = data.loc[data["Population Density (per m^2)"]> 250]
high_den_df.head()
# Out:
#     Unnamed: 0      County      State  Total Population  Land Area (m^2)  \
# 13          13   McCracken   Kentucky           65485.0           248.74
# 26          26      Oldham   Kentucky           66508.0           187.22
# 55          55       Anoka  Minnesota          353775.0           423.01
# 61          61      Carver  Minnesota          103561.0           354.33
# 66          66  Montgomery  Tennessee          204992.0           539.18
#
#     Population Density (per m^2)  Median Gross Rent  Income per capita  \
# 13                    263.266865              744.0            30044.0
# 26                    355.239825              964.0            44186.0
# 55                    836.327746             1162.0            37804.0
# 61                    292.272740             1170.0            48492.0
# 66                    380.192144              972.0            28032.0
#
#     Less Than A High School Diploma, 2017-21  \
# 13                                    3582.0
# ...

# %% [markdown]
# ### High Pop Density
# #### Base Stats
