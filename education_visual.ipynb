# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import os

# %%
filepath = "C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\full_data.csv"
data = pd.read_csv(filepath)
#data.head()

complete_df = data.loc[~data.duplicated(subset=['County','State'])]
complete_df.describe()
# Out:
#         Unnamed: 0  Total Population  Land Area (m^2)  \
# count  2834.000000      2.834000e+03      2834.000000
# mean   1427.317572      9.752344e+04       942.879178
# std     823.134290      2.752445e+05      1259.777794
# min       0.000000      2.790000e+02        24.160000
# 25%     716.250000      1.109750e+04       433.522500
# 50%    1425.500000      2.569750e+04       609.195000
# 75%    2140.750000      6.654850e+04       909.612500
# max    2850.000000      5.169517e+06     18618.890000
#
#        Population Density (per m^2)  Median Gross Rent  Income per capita  \
# count                   2834.000000        2834.000000        2834.000000
# mean                     211.278574         777.070572       28858.539520
# std                     1195.144933         220.913049        6704.255247
# min                        0.203252         325.000000       10280.000000
# 25%                       17.223321         644.000000       24442.250000
# ...

# %% [markdown]
# ## Education Visualizations

# %% [markdown]
# ### Low Pop Density
# #### Base Stats

# %%
# create data frame
low_den_df = complete_df.loc[complete_df["Population Density (per m^2)"] < 250]
#low_den_df.head()
#low_den_df.columns

# %%
xValues = low_den_df["Population Density (per m^2)"]
yLHS = low_den_df["Less Than A High School Diploma, 2017-21"]
yHS = low_den_df["High School Diploma Only, 2017-21"]
ySC = low_den_df["Some College Or Associate'S Degree, 2017-21"]
yBD = low_den_df["Bachelor'S Degree Or Higher, 2017-21"]

# %%
plt.scatter(xValues, yLHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Number of people with \n Less than a High School Diploma")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yLHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 100000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-less-than-hs-diploma.png", bbox_inches="tight")

# %%
plt.scatter(xValues, yHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Number of People with \n High School Diploma Only")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 100000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-hs-diploma-only", bbox_inches="tight")

# %%
plt.scatter(xValues, ySC, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Number of People with \n Some College or Associate's Degree")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, ySC)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 150000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-some-college", bbox_inches="tight")

# %%
plt.scatter(xValues, yBD, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Number of People with \n Bachelor's Degree or Higher")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yBD)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 200000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\low-pop-bachelors-degree", bbox_inches="tight")

# %% [markdown]
# ### Low Pop Density
# #### Percent Stats

# %%
xValues = low_den_df["Population Density (per m^2)"]
ypLHS = low_den_df["Percent Of Adults With Less Than A High School Diploma, 2017-21"]
ypHS = low_den_df["Percent Of Adults With A High School Diploma Only, 2017-21"]
ypSC = low_den_df["Percent Of Adults Completing Some College Or Associate'S Degree, 2017-21"]
ypBD = low_den_df["Percent Of Adults With A Bachelor'S Degree Or Higher, 2017-21"]

# %%
plt.scatter(xValues, ypLHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults with \n Less than a High School Diploma")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, ypLHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 45))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-less-than-hs-diploma", bbox_inches="tight")

# %%
plt.scatter(xValues, ypHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults with \n a High School Diploma only")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, ypHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 50))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-hs-diploma-only", bbox_inches="tight")

# %%
plt.scatter(xValues, ypSC, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults who have \n Completed some College or Associate's Degree")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, ypSC)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 45))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-some-college", bbox_inches="tight")

# %%
plt.scatter(xValues, ypBD, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults with \n a Bachelor's Degree or Higher")
plt.xlabel("Population Density Below 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, ypBD)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(150, 60))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-low-pop-bachelors-degree", bbox_inches="tight")

# %% [markdown]
# ### High Pop Density
# #### Base Stats

# %%
#create data frame
high_den_df = complete_df.loc[complete_df["Population Density (per m^2)"]> 250]
high_den_df.head()
#high_den_df.describe()
# Out:
#     Unnamed: 0      County      State  Total Population  Land Area (m^2)  \
# 13          13   McCracken   Kentucky           65485.0           248.74
# 26          26      Oldham   Kentucky           66508.0           187.22
# 55          55       Anoka  Minnesota          353775.0           423.01
# 61          61      Carver  Minnesota          103561.0           354.33
# 66          66  Montgomery  Tennessee          204992.0           539.18
#
#     Population Density (per m^2)  Median Gross Rent  Income per capita  \
# 13                    263.266865              744.0            30044.0
# 26                    355.239825              964.0            44186.0
# 55                    836.327746             1162.0            37804.0
# 61                    292.272740             1170.0            48492.0
# 66                    380.192144              972.0            28032.0
#
#     Less Than A High School Diploma, 2017-21  \
# 13                                    3582.0
# ...

# %% [markdown]
# ### High Pop Density
# #### Base Stats

# %%
xValues = high_den_df["Population Density (per m^2)"]
yhLHS = high_den_df["Less Than A High School Diploma, 2017-21"]
yhHS = high_den_df["High School Diploma Only, 2017-21"]
yhSC = high_den_df["Some College Or Associate'S Degree, 2017-21"]
yhBD = high_den_df["Bachelor'S Degree Or Higher, 2017-21"]

# %%
plt.scatter(xValues, yhLHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Number of people with \n Less Than A High School Diploma")
plt.xlabel("Population Density Above 250 (per m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhLHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 400000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\high-pop-less-than-hs-diploma", bbox_inches="tight")

# %%
plt.scatter(xValues, yhHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (m^2) vs Number of people with \n High School Diploma Only")
plt.xlabel("Population Density Above 250 (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 600000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\high-pop-hs-diploma-only", bbox_inches="tight")

# %%
plt.scatter(xValues, yhSC, edgecolors = 'black', alpha = .3)

plt.title("Population Density (m^2) vs Number of people with \n Some College or Associate's Degree")
plt.xlabel("Population Density Above 250 (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhSC)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 600000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\high-pop-some-college", bbox_inches="tight")

# %%
plt.scatter(xValues, yhBD, edgecolors = 'black', alpha = .3)

plt.title("Population Density (m^2) vs Number of people with \n Bachelor's Degree Or Higher")
plt.xlabel("Population Density Above 250 (m^2)")
plt.ylabel("Number of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhBD)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 1000000))
plt.plot(xValues, regress_values, "r-")

#plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\high-pop-bachelors-degree", bbox_inches="tight")

# %% [markdown]
# ### High Pop Density
# #### Percent Stats

# %%
xValues = high_den_df["Population Density (per m^2)"]
yhpLHS = high_den_df["Percent Of Adults With Less Than A High School Diploma, 2017-21"]
yhpHS = high_den_df["Percent Of Adults With A High School Diploma Only, 2017-21"]
yhpSC = high_den_df["Percent Of Adults Completing Some College Or Associate'S Degree, 2017-21"]
yhpBD = high_den_df["Percent Of Adults With A Bachelor'S Degree Or Higher, 2017-21"]

# %%
plt.scatter(xValues, yhpLHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults with \n Less than a High School Diploma")
plt.xlabel("Population Density Above 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhpLHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 25))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-high-pop-less-than-hs-diploma", bbox_inches="tight")

# %%
plt.scatter(xValues, yhpHS, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults with \n a High School Diploma only")
plt.xlabel("Population Density Above 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhpHS)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 35))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-high-pop-hs-diploma-only", bbox_inches="tight")

# %%
plt.scatter(xValues, yhpSC, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults \n Completing Some College Or Associate's Degree")
plt.xlabel("Population Density Above 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhpSC)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 35))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-high-pop-some-college", bbox_inches="tight")

# %%
plt.scatter(xValues, yhpBD, edgecolors = 'black', alpha = .3)

plt.title("Population Density (per m^2) vs Percent of Adults \n a Bachelor's Degree or Higher")
plt.xlabel("Population Density Above 250 (per m^2)")
plt.ylabel("Percent of People")

(slope, intercept, rvalue, pvalue, stderr) = linregress(xValues, yhpBD)
regress_values = xValues * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}\nR-value = {round(rvalue,2)}"

plt.plot(xValues,regress_values,"r-")
plt.annotate(line_eq,fontsize=12,color="red", xy=(20000, 60))
plt.plot(xValues, regress_values, "r-")

plt.savefig("C:\\Users\\ginav\\Desktop\\Analysis Projects\\Project 1\\Project-1\\percent-high-pop-bachelors-degree", bbox_inches="tight")
